# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
mba = pd.read_csv("MBA.csv")
mba['gender'].replace('Female', 1,inplace=True)
mba['gender'].replace('Male', 1,inplace=True)
mba['international'].replace(False , 0,inplace=True)
mba['international'].replace(True , 1,inplace=True)
mba.loc[mba.major =="STEM", 'major'] = 1
mba.loc[mba.major != 1, 'major'] = 0
mba.loc[mba.work_industry =="Technology", 'work_industry'] = 1
mba.loc[mba.work_industry != 1, 'work_industry'] = 0

mba.loc[mba.admission =="Admit", 'admission'] = 1
mba.loc[mba.admission != 1, 'admission'] = 0


y =  mba["admission"]
X = mba.loc[:, mba.columns != 'admision']
X = X.loc[:, X.columns != 'aplication_id']
X = X.loc[:, X.columns != 'race']
X = X.round()
y = pd.to_numeric(y)

# %%
X.corr()
# Out:
#                 application_id  gender  international       gpa     major  \
# application_id        1.000000     NaN       0.008045  0.000146 -0.015848
# gender                     NaN     NaN            NaN       NaN       NaN
# international         0.008045     NaN       1.000000 -0.012577  0.000311
# gpa                   0.000146     NaN      -0.012577  1.000000 -0.002966
# major                -0.015848     NaN       0.000311 -0.002966  1.000000
# gmat                  0.004694     NaN      -0.014784  0.288301 -0.003489
# work_exp              0.003100     NaN      -0.010341  0.007028  0.005179
# work_industry        -0.004144     NaN      -0.001024 -0.005104 -0.010707
# admission            -0.095261     NaN       0.010377  0.158088 -0.009414
#
#                     gmat  work_exp  work_industry  admission
# application_id  0.004694  0.003100      -0.004144  -0.095261
# gender               NaN       NaN            NaN        NaN
# international  -0.014784 -0.010341      -0.001024   0.010377
# gpa             0.288301  0.007028      -0.005104   0.158088
# major          -0.003489  0.005179      -0.010707  -0.009414
# gmat            1.000000 -0.000999       0.001817   0.348319
# work_exp       -0.000999  1.000000      -0.012784   0.011868
# work_industry   0.001817 -0.012784       1.000000   0.011411
# admission       0.348319  0.011868       0.011411   1.000000

# %%
train_score=[]
test_score =[]
test_size =[]
for i in range(10,90,1):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i/100, random_state=42)

    svm = SVC(kernel="rbf")
    svm.fit(X_train, y_train)
    
    svm.predict(X_train)
    train_score.append(svm.score(X_train, y_train))
    
    svm.predict(X_test)
    test_score.append(svm.score(X_test, y_test))
    
    test_size.append(i/100)

# %%
plt.plot(test_size,train_score)
plt.xlabel("train_size")
plt.ylabel("train_score")
# Out:
# Text(0, 0.5, 'train_score')

# %%
plt.plot(test_size,test_score)
plt.xlabel("train_size")
plt.ylabel("test_score")
# Out:
# Text(0, 0.5, 'test_score')

# %%
train_score=[]
test_score =[]
test_size =[]
for i in range(10,90,1):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i/100, random_state=42)

    svm = SVC(kernel="sigmoid")
    svm.fit(X_train, y_train)
    
    svm.predict(X_train)
    train_score.append(svm.score(X_train, y_train))
    
    svm.predict(X_test)
    test_score.append(svm.score(X_test, y_test))
    
    test_size.append(i/100)

# %%
plt.plot(test_size,train_score)
plt.xlabel("train_size")
plt.ylabel("train_score")
# Out:
# Text(0, 0.5, 'train_score')

# %%
plt.plot(test_size,test_score)
plt.xlabel("train_size")
plt.ylabel("test_score")
# Out:
# Text(0, 0.5, 'test_score')

# %%
train_score=[]
test_score =[]
test_size =[]
for i in range(10,90,1):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i/100, random_state=42)

    svm = SVC(kernel="poly")
    svm.fit(X_train, y_train)
    
    svm.predict(X_train)
    train_score.append(svm.score(X_train, y_train))
    
    svm.predict(X_test)
    test_score.append(svm.score(X_test, y_test))
    
    test_size.append(i/100)

# %%
plt.plot(test_size,train_score)
plt.xlabel("train_size")
plt.ylabel("train_score")
# Out:
# Text(0, 0.5, 'train_score')

# %%
plt.plot(test_size,test_score)
plt.xlabel("train_size")
plt.ylabel("test_score")
# Out:
# Text(0, 0.5, 'test_score')

# %%
train_score=[]
test_score =[]
test_size =[]
for i in range(10,200,10):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.60, random_state=42)

    svm = SVC(kernel="rbf", gamma = i/100)
    svm.fit(X_train, y_train)
    
    svm.predict(X_train)
    train_score.append(svm.score(X_train, y_train))
    
    svm.predict(X_test)
    test_score.append(svm.score(X_test, y_test))
    
    test_size.append(i/100)
    
plt.plot(test_size,test_score)
plt.xlabel("train_size")
plt.ylabel("test_score")
# Out:
# Text(0, 0.5, 'test_score')

# %%
train_score=[]
test_score =[]
test_size =[]
for i in range(10,100,10):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.60, random_state=42)

    svm = SVC(kernel="rbf", C= i)
    svm.fit(X_train, y_train)
    
    svm.predict(X_train)
    train_score.append(svm.score(X_train, y_train))
    
    svm.predict(X_test)
    test_score.append(svm.score(X_test, y_test))
    
    test_size.append(i/100)
    
plt.plot(test_size,test_score)
plt.xlabel("train_size")
plt.ylabel("test_score")
# Out:
# Text(0, 0.5, 'test_score')
